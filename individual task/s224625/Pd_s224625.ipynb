# %% [markdown]
# # Introduction

# %% [markdown]
# Hopefully, this short tutorial can show you a lot of different commands that will help you gain the most insights into your dataset.

# %%
import pandas as pd
from src.utils import load_data_from_google_drive

# %% [markdown]
# # Loading in Data

# %% [markdown]
# The first step in any ML problem is identifying what format your data is in, and then loading it into whatever framework you're using. For Kaggle compeitions, a lot of data can be found in CSV files, so that's the example we're going to use.

# %% [markdown]
# We're going to be looking at a sports dataset that shows the results from NCAA basketball games from 1985 to 2016. This dataset is in a CSV file, and the function we're going to use to read in the file is called **pd.read_csv()**. This function returns a **dataframe** variable. The dataframe is the golden jewel data structure for Pandas. It is defined as "a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns)".

# %% [markdown]
# Just think of it as a table for now.

# %%
df = load_data_from_google_drive(url='https://drive.google.com/file/d/184JcLbSpArA_uq0DgAv2k892KChJVPHt/view?usp=share_link')

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %% [markdown]
# # The Basics

# %% [markdown]
# Now that we have our dataframe in our variable df, let's look at what it contains. We can use the function **head()** to see the first couple rows of the dataframe (or the function **tail()** to see the last few rows).

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %%
df.tail()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %% [markdown]
# We can see the dimensions of the dataframe using the the **shape** attribute

# %%
df.shape
# Out:
# (145289, 8)

# %% [markdown]
# We can also extract all the column names as a list, by using the **columns** attribute and can extract the rows with the **index** attribute

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %% [markdown]
# In order to get a better idea of the type of data that we are dealing with, we can call the **describe()** function to see statistics like mean, min, etc about each column of the dataset.

# %%
df.describe()
# Out:
#               Season         Daynum          Wteam         Wscore  \
# count  145289.000000  145289.000000  145289.000000  145289.000000
# mean     2001.574834      75.223816    1286.720646      76.600321
# std         9.233342      33.287418     104.570275      12.173033
# min      1985.000000       0.000000    1101.000000      34.000000
# 25%      1994.000000      47.000000    1198.000000      68.000000
# 50%      2002.000000      78.000000    1284.000000      76.000000
# 75%      2010.000000     103.000000    1379.000000      84.000000
# max      2016.000000     132.000000    1464.000000     186.000000
#
#                Lteam         Lscore          Numot
# count  145289.000000  145289.000000  145289.000000
# mean     1282.864064      64.497009       0.044387
# std       104.829234      11.380625       0.247819
# min      1101.000000      20.000000       0.000000
# 25%      1191.000000      57.000000       0.000000
# 50%      1280.000000      64.000000       0.000000
# 75%      1375.000000      72.000000       0.000000
# max      1464.000000     150.000000       6.000000

# %% [markdown]
# Okay, so now let's looking at information that we want to extract from the dataframe. Let's say I wanted to know the max value of a certain column. The function **max()** will show you the maximum values of all columns

# %%
df.max()
# Out:
# Season    2016
# Daynum     132
# Wteam     1464
# Wscore     186
# Lteam     1464
# Lscore     150
# Wloc         N
# Numot        6
# dtype: object

# %% [markdown]
# Then, if you'd like to specifically get the max value for a particular column, you pass in the name of the column using the bracket indexing operator

# %%
df['Wscore'].max()
# Out:
# 186

# %% [markdown]
# If you'd like to find the mean of the Losing teams' score.

# %%
df['Lscore'].mean()
# Out:
# 64.49700940883343

# %% [markdown]
# But what if that's not enough? Let's say we want to actually see the game(row) where this max score happened. We can call the **argmax()** function to identify the row index

# %%
df['Wscore'].argmax()
# Out:
# 24970

# %% [markdown]
# One of the most useful functions that you can call on certain columns in a dataframe is the **value_counts()** function. It shows how many times each item appears in the column. This particular command shows the number of games in each season

# %%
df['Season'].value_counts()
# Out:
# 2016    5369
# 2014    5362
# 2015    5354
# 2013    5320
# 2010    5263
# 2012    5253
# 2009    5249
# 2011    5246
# 2008    5163
# 2007    5043
# 2006    4757
# 2005    4675
# 2003    4616
# 2004    4571
# 2002    4555
# 2000    4519
# 2001    4467
# 1999    4222
# 1998    4167
# 1997    4155
# 1992    4127
# 1991    4123
# 1996    4122
# 1995    4077
# 1994    4060
# 1990    4045
# 1989    4037
# 1993    3982
# 1988    3955
# 1987    3915
# 1986    3783
# 1985    3737
# Name: Season, dtype: int64

# %% [markdown]
# **Q**: How many unique seasons are there in the dataset? Use the nunique() function.

# %%
Useasons = df['Season'].nunique()
print("Number of unique seasons:", Useasons)
# Out:
# Number of unique seasons: 32

# %% [markdown]
# **Q**: Find the team with the most wins. Use the value_counts() function on the Wteam column.

# %%
Team_Wins = df['Wteam'].value_counts().idxmax()
print("Team with the most wins:", Team_Wins)
# Out:
# Team with the most wins: 1181

# %% [markdown]
# # Acessing Values

# %% [markdown]
# Then, in order to get attributes about the game, we need to use the **iloc[]** function. Iloc is definitely one of the more important functions. The main idea is that you want to use it whenever you have the integer index of a certain row that you want to access. As per Pandas documentation, iloc is an "integer-location based indexing for selection by position."

# %%
df.iloc[[df['Wscore'].argmax()]]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0

# %% [markdown]
# Let's take this a step further. Let's say you want to know the game with the highest scoring winning team (this is what we just calculated), but you then want to know how many points the losing team scored.

# %%
df.iloc[[df['Wscore'].argmax()]]['Lscore']
# Out:
# 24970    140
# Name: Lscore, dtype: int64

# %% [markdown]
# When you see data displayed in the above format, you're dealing with a Pandas **Series** object, not a dataframe object.

# %%
type(df.iloc[[df['Wscore'].argmax()]]['Lscore'])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[[df['Wscore'].argmax()]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The following is a summary of the 3 data structures in Pandas (Haven't ever really used Panels yet)
#
# ![](DataStructures.png)

# %% [markdown]
# When you want to access values in a Series, you'll want to just treat the Series like a Python dictionary, so you'd access the value according to its key (which is normally an integer index)

# %%
df.iloc[[df['Wscore'].argmax()]]['Lscore'][24970]
# Out:
# 140

# %% [markdown]
# The other really important function in Pandas is the **loc** function. Contrary to iloc, which is an integer based indexing, loc is a "Purely label-location based indexer for selection by label". Since all the games are ordered from 0 to 145288, iloc and loc are going to be pretty interchangable in this type of dataset

# %%
df.iloc[:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0

# %%
df.loc[:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0

# %% [markdown]
# Notice the slight difference in that iloc is exclusive of the second number, while loc is inclusive.

# %% [markdown]
# Below is an example of how you can use loc to acheive the same task as we did previously with iloc

# %%
df.loc[df['Wscore'].argmax(), 'Lscore']
# Out:
# 140

# %% [markdown]
# A faster version uses the **at()** function. At() is really useful wheneever you know the row label and the column label of the particular value that you want to get.

# %%
df.at[df['Wscore'].argmax(), 'Lscore']
# Out:
# 140

# %% [markdown]
# If you'd like to see more discussion on how loc and iloc are different, check out this great Stack Overflow post: http://stackoverflow.com/questions/31593201/pandas-iloc-vs-ix-vs-loc-explanation. Just remember that **iloc looks at position** and **loc looks at labels**. Loc becomes very important when your row labels aren't integers.

# %% [markdown]
# # Sorting

# %% [markdown]
# Let's say that we want to sort the dataframe in increasing order for the scores of the losing team

# %%
df.sort_values('Lscore').head()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 100027    2008      66   1203      49   1387      20    H      0
# 49310     1997      66   1157      61   1204      21    H      0
# 89021     2006      44   1284      41   1343      21    A      0
# 85042     2005      66   1131      73   1216      22    H      0
# 103660    2009      26   1326      59   1359      22    H      0

# %% [markdown]
# **Q**: Make three dataframes that are sorted by season, winning team, and winning score respectively. Then, Using iloc, select the rows from index 100 to 200 and the columns for season, winning team, and winning score, respectively.

# %%
# Sort DataFrame by season
df_sorted_by_season = df.sort_values('Season')
print("Sorted by season:")
display(df_sorted_by_season.head())

# Sort DataFrame by winning team
df_sorted_by_winning_team = df.sort_values('Wteam')
print("Sorted by winning team:")
display(df_sorted_by_winning_team.head())

# Sort DataFrame by winning score
df_sorted_by_winning_score = df.sort_values('Wscore')
print("Sorted by winning score:")
display(df_sorted_by_winning_score.head())
# Out:
# Sorted by season:
#       Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0       1985      20   1228      81   1328      64    N      0
# 2484    1985      99   1275      73   1132      63    H      0
# 2485    1985      99   1306      62   1171      59    H      0
# 2486    1985      99   1318      99   1145      91    H      0
# 2487    1985      99   1337      75   1109      56    H      0
# Sorted by winning team:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 140642    2016      25   1101      72   1197      62    N      0
# 136740    2015      62   1101      87   1146      70    H      0
# 143283    2016      89   1101      80   1249      71    H      0
# 143476    2016      92   1101      79   1223      72    H      0
# 141972    2016      61   1101      62   1146      61    A      0
# Sorted by winning score:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 128582    2013     116   1264      34   1193      31    H      0
# 69336     2001     126   1206      35   1423      33    N      0
# 5364      1986      77   1229      35   1166      34    A      0
# 20246     1990      47   1374      36   1426      31    H      0
# 118590    2011     130   1336      36   1458      33    N      0

# %%
df.iloc[100:201][["Season","Wteam","Wscore"]]
# Out:
#      Season  Wteam  Wscore
# 100    1985   1409      86
# 101    1985   1444      90
# 102    1985   1451      89
# 103    1985   1139      78
# 104    1985   1154      78
# ..      ...    ...     ...
# 196    1985   1203      83
# 197    1985   1222      73
# 198    1985   1227      76
# 199    1985   1228      73
# 200    1985   1229      54
#
# [101 rows x 3 columns]

# %% [markdown]
# **Q**: From these three subsets you obtained above, find the season and winning team for the game with the highest winning score.

# %%
# Find the game with the highest winning score in each subset
max_winning_score_season_sorted_by_season = df_sorted_by_season[df_sorted_by_season['Wscore'] == df_sorted_by_season['Wscore'].max()]['Season'].values[0]
max_winning_score_team_sorted_by_season = df_sorted_by_season[df_sorted_by_season['Wscore'] == df_sorted_by_season['Wscore'].max()]['Wteam'].values[0]

max_winning_score_season_sorted_by_winning_team = df_sorted_by_winning_team[df_sorted_by_winning_team['Wscore'] == df_sorted_by_winning_team['Wscore'].max()]['Season'].values[0]
max_winning_score_team_sorted_by_winning_team = df_sorted_by_winning_team[df_sorted_by_winning_team['Wscore'] == df_sorted_by_winning_team['Wscore'].max()]['Wteam'].values[0]

max_winning_score_season_sorted_by_winning_score = df_sorted_by_winning_score[df_sorted_by_winning_score['Wscore'] == df_sorted_by_winning_score['Wscore'].max()]['Season'].values[0]
max_winning_score_team_sorted_by_winning_score = df_sorted_by_winning_score[df_sorted_by_winning_score['Wscore'] == df_sorted_by_winning_score['Wscore'].max()]['Wteam'].values[0]

# Print the results
print("From the subset sorted by season:")
print("Season:", max_winning_score_season_sorted_by_season)
print("Winning team:", max_winning_score_team_sorted_by_season)

print("\nFrom the subset sorted by winning team:")
print("Season:", max_winning_score_season_sorted_by_winning_team)
print("Winning team:", max_winning_score_team_sorted_by_winning_team)

print("\nFrom the subset sorted by winning score:")
print("Season:", max_winning_score_season_sorted_by_winning_score)
print("Winning team:", max_winning_score_team_sorted_by_winning_score)
# Out:
# From the subset sorted by season:
# Season: 1991
# Winning team: 1258
#
# From the subset sorted by winning team:
# Season: 1991
# Winning team: 1258
#
# From the subset sorted by winning score:
# Season: 1991
# Winning team: 1258

# %% [markdown]
# Since the three dataframes provide the same result, it attests to the fact that the dataframes offer the same accurate information.

# %% [markdown]
# # Filtering Rows Conditionally

# %% [markdown]
# Now, let's say we want to find all of the rows that satisy a particular condition. For example, I want to find all of the games where the winning team scored more than 150 points. The idea behind this command is you want to access the column 'Wscore' of the dataframe df (df['Wscore']), find which entries are above 150 (df['Wscore'] > 150), and then returns only those specific rows in a dataframe format (df[df['Wscore'] > 150]).

# %%
df[df['Wscore'] > 150]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 5269     1986      75   1258     151   1109     107    H      0
# 12046    1988      40   1328     152   1147      84    H      0
# 12355    1988      52   1328     151   1173      99    N      0
# 16040    1989      40   1328     152   1331     122    H      0
# 16853    1989      68   1258     162   1109     144    A      0
# 17867    1989      92   1258     181   1109     150    H      0
# 19653    1990      30   1328     173   1109     101    H      0
# 19971    1990      38   1258     152   1109     137    A      0
# 20022    1990      40   1116     166   1109     101    H      0
# 22145    1990      97   1258     157   1362     115    H      0
# 23582    1991      26   1318     152   1258     123    N      0
# 24341    1991      47   1328     172   1258     112    H      0
# 24970    1991      68   1258     186   1109     140    H      0
# 25656    1991      84   1106     151   1212      97    H      0
# 28687    1992      54   1261     159   1319      86    H      0
# 35023    1993     112   1380     155   1341      91    A      0
# 40060    1995      32   1375     156   1341     114    H      0
# 52600    1998      33   1395     153   1410      87    H      0

# %% [markdown]
# This also works if you have multiple conditions. Let's say we want to find out when the winning team scores more than 150 points and when the losing team scores below 100.

# %%
df[(df['Wscore'] > 150) & (df['Lscore'] < 100)]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 12046    1988      40   1328     152   1147      84    H      0
# 12355    1988      52   1328     151   1173      99    N      0
# 25656    1991      84   1106     151   1212      97    H      0
# 28687    1992      54   1261     159   1319      86    H      0
# 35023    1993     112   1380     155   1341      91    A      0
# 52600    1998      33   1395     153   1410      87    H      0

# %% [markdown]
# **Q**: Create a new column in the DataFrame called 'ScoreDifference' which is the absolute difference between the winning score and the losing score. Filter the DataFrame to only include games where the 'ScoreDifference' is greater than the average 'ScoreDifference' for all games.

# %%
# Create a new column 'ScoreDifference'
df['ScoreDifference'] = abs(df['Wscore'] - df['Lscore'])

# Calculate the average 'ScoreDifference' for all games
average_score_difference = df['ScoreDifference'].mean()

# Filter the DataFrame based on the condition
filtered_df = df[df['ScoreDifference'] > average_score_difference]

# Print the filtered DataFrame using display()
print("Filtered DataFrame:")
print(filtered_df)
display(filtered_df)
# Out:
# Filtered DataFrame:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  \
# 0         1985      20   1228      81   1328      64    N      0
# 3         1985      25   1165      70   1432      54    H      0
# 6         1985      25   1228      64   1226      44    N      0
# 8         1985      25   1260      98   1133      80    H      0
# 10        1985      25   1307     103   1288      71    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145280    2016     131   1401      71   1261      38    N      0
# 145282    2016     131   1433      76   1172      54    N      0
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
#         ScoreDifference
# 0                    17
# 3                    16
# 6                    20
# 8                    18
# 10                   32
# ...                 ...
# 145280               33
# 145282               22
# 145284               20
# 145285               14
# 145288               13
#
# [57227 rows x 9 columns]
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  \
# 0         1985      20   1228      81   1328      64    N      0
# 3         1985      25   1165      70   1432      54    H      0
# 6         1985      25   1228      64   1226      44    N      0
# 8         1985      25   1260      98   1133      80    H      0
# 10        1985      25   1307     103   1288      71    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145280    2016     131   1401      71   1261      38    N      0
# 145282    2016     131   1433      76   1172      54    N      0
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
#         ScoreDifference
# 0                    17
# 3                    16
# 6                    20
# 8                    18
# 10                   32
# ...                 ...
# 145280               33
# 145282               22
# 145284               20
# 145285               14
# 145288               13
#
# [57227 rows x 9 columns]

# %% [markdown]
# **Q**: From this filtered DataFrame, find the season and teams involved in the game with the highest 'ScoreDifference'.

# %%
# Find the game with the highest 'ScoreDifference' in the filtered DataFrame
max_score_difference_game = filtered_df[filtered_df['ScoreDifference'] == filtered_df['ScoreDifference'].max()]

# Get the season and teams involved in the game
season = max_score_difference_game['Season'].values[0]
winning_team = max_score_difference_game['Wteam'].values[0]
losing_team = max_score_difference_game['Lteam'].values[0]

# Print the results
print("Season:", season)
print("Winning Team:", winning_team)
print("Losing Team:", losing_team)
# Out:
# Season: 1996
# Winning Team: 1409
# Losing Team: 1341

# %% [markdown]
# # Grouping

# %% [markdown]
# Another important function in Pandas is **groupby()**. This is a function that allows you to group entries by certain attributes (e.g Grouping entries by Wteam number) and then perform operations on them. The following function groups all the entries (games) with the same Wteam number and finds the mean for each group.

# %%
df.groupby('Wteam')['Wscore'].mean().head()
# Out:
# Wteam
# 1101    78.111111
# 1102    69.893204
# 1103    75.839768
# 1104    75.825944
# 1105    74.960894
# Name: Wscore, dtype: float64

# %% [markdown]
# This next command groups all the games with the same Wteam number and finds where how many times that specific team won at home, on the road, or at a neutral site

# %%
df.groupby('Wteam')['Wloc'].value_counts().head(9)
# Out:
# Wteam  Wloc
# 1101   H        12
#        A         3
#        N         3
# 1102   H       204
#        A        73
#        N        32
# 1103   H       324
#        A       153
#        N        41
# Name: Wloc, dtype: int64

# %% [markdown]
# Each dataframe has a **values** attribute which is useful because it basically displays your dataframe in a numpy array style format

# %%
df.values
# Out:
# array([[1985, 20, 1228, ..., 'N', 0, 17],
#        [1985, 25, 1106, ..., 'H', 0, 7],
#        [1985, 25, 1112, ..., 'H', 0, 7],
#        ...,
#        [2016, 132, 1246, ..., 'N', 1, 5],
#        [2016, 132, 1277, ..., 'N', 0, 4],
#        [2016, 132, 1386, ..., 'N', 0, 13]], dtype=object)

# %% [markdown]
# Now, you can simply just access elements like you would in an array.

# %%
df.values[0][0]
# Out:
# 1985

# %% [markdown]
# **Q**: Group the DataFrame by season and find the average winning score for each season.

# %%
df.groupby('Season').mean("Wscore")
# Out:
#            Daynum        Wteam     Wscore        Lteam     Lscore     Numot  \
# Season
# 1985    81.817233  1287.701097  74.723040  1281.085898  63.860316  0.007760
# 1986    81.445678  1285.545863  74.813640  1282.876024  63.633888  0.002115
# 1987    82.907535  1284.852107  77.993870  1283.150192  66.770626  0.008429
# 1988    79.438938  1284.863970  79.773704  1284.150695  67.697092  0.003793
# 1989    79.123854  1283.772851  81.728511  1285.397325  69.530840  0.005697
# 1990    79.195303  1282.814339  80.846477  1284.844499  68.833622  0.006180
# 1991    78.725928  1287.633519  82.733932  1282.486054  70.057240  0.007519
# 1992    76.514660  1285.796947  79.992004  1284.502060  67.144657  0.003150
# 1993    81.057258  1286.536414  79.508790  1285.797589  67.301858  0.004771
# 1994    80.279557  1287.935468  81.160345  1286.099261  68.561330  0.005665
# 1995    79.828550  1291.149129  80.096149  1280.886191  67.394898  0.008094
# 1996    79.872392  1288.701601  78.205483  1284.702572  65.737506  0.007035
# 1997    80.003369  1286.539832  76.300842  1285.100602  63.742238  0.007942
# 1998    78.013679  1288.089753  77.229902  1284.805136  64.612911  0.005040
# 1999    76.980341  1286.234249  76.043581  1284.950024  63.427996  0.008053
# 2000    75.169285  1287.418677  76.310467  1281.264882  63.870768  0.066608
# 2001    75.721289  1285.600627  77.088650  1282.611372  64.833221  0.073651
# 2002    75.277497  1286.658836  76.963557  1281.581120  64.614270  0.065642
# 2003    74.808709  1285.591854  75.795061  1281.750867  63.756932  0.061308
# 2004    75.335156  1285.931306  74.971122  1280.900678  62.990155  0.071319
# 2005    75.042567  1286.067166  74.693690  1282.088770  62.635294  0.066524
# 2006    74.712634  1283.769182  74.587555  1285.425478  62.666597  0.073996
# 2007    71.676780  1286.476700  74.829467  1283.896887  62.761650  0.067618
# 2008    68.392020  1288.741817  74.962425  1281.907418  62.755375  0.072439
# 2009    70.963612  1287.680511  74.033721  1281.312250  61.980377  0.071633
# 2010    70.741212  1289.607638  74.652480  1279.997910  62.484325  0.063272
# 2011    70.881243  1285.244758  74.374190  1283.078727  62.470644  0.077964
# 2012    70.745479  1286.596802  73.379973  1283.055778  61.415953  0.070055
# 2013    68.058647  1284.684211  72.840789  1285.594361  60.908083  0.072744
# 2014    68.882507  1288.116561  76.101268  1280.580940  64.452070  0.082991
# 2015    70.742249  1288.073963  72.680799  1279.929399  61.007845  0.079380
# 2016    70.922332  1289.136711  78.295958  1279.221270  66.327063  0.078413
#
#         ScoreDifference
# Season
# 1985          10.862724
# 1986          11.179752
# 1987          11.223244
# 1988          12.076612
# 1989          12.197672
# 1990          12.012855
# 1991          12.676692
# 1992          12.847347
# 1993          12.206931
# 1994          12.599015
# 1995          12.701251
# 1996          12.467977
# 1997          12.558604
# 1998          12.616991
# 1999          12.615585
# 2000          12.439699
# 2001          12.255429
# 2002          12.349286
# 2003          12.038128
# 2004          11.980967
# 2005          12.058396
# 2006          11.920959
# 2007          12.067817
# 2008          12.207050
# 2009          12.053343
# 2010          12.168155
# 2011          11.903546
# 2012          11.964021
# 2013          11.932707
# 2014          11.649198
# 2015          11.672955
# 2016          11.968896

# %% [markdown]
# **Q**: Group the DataFrame by winning team and find the maximum winning score for each team across all seasons.

# %%
df.groupby('Wteam').max('Wscore')
# Out:
#        Season  Daynum  Wscore  Lteam  Lscore  Numot  ScoreDifference
# Wteam
# 1101     2016     120      95   1368      84      0               17
# 1102     2016     129     111   1464      94      3               45
# 1103     2016     131     109   1464     104      2               58
# 1104     2016     132     114   1464     101      3               57
# 1105     2016     132     114   1445      93      2               37
# ...       ...     ...     ...    ...     ...    ...              ...
# 1460     2016     131     136   1464     113      2               66
# 1461     2016     132     112   1457      98      4               53
# 1462     2016     131     125   1464     113      3               57
# 1463     2016     131     105   1447      96      2               39
# 1464     2016     126     115   1460     101      2               34
#
# [364 rows x 7 columns]

# %% [markdown]
# **Q**: Group the DataFrame by both season and winning team. Find the team with the highest average winning score for each season.

# %%
# Group the DataFrame by season and winning team
grouped_df = df.groupby(['Season', 'Wteam'])

# Find the team with the highest average winning score for each season
highest_avg_score_per_season = grouped_df['Wscore'].mean().groupby('Season').idxmax()

# Create an empty list to store the result rows
result_rows = []

# Populate the list with the result rows
for season, team_index in highest_avg_score_per_season.items():
    winning_team = team_index[1]
    avg_score = grouped_df.get_group(team_index)['Wscore'].mean()
    result_rows.append({'Season': season, 'Winning Team': winning_team, 'Average Winning Score': avg_score})

# Create a new DataFrame with the results
result_df = pd.DataFrame(result_rows)

# Print the resulting DataFrame
print("Teams with the highest average winning score for each season:")
display(result_df)
# Out:
# Teams with the highest average winning score for each season:
#     Season  Winning Team  Average Winning Score
# 0     1985          1328              92.800000
# 1     1986          1109              91.200000
# 2     1987          1380              95.875000
# 3     1988          1258             111.750000
# 4     1989          1258             117.315789
# 5     1990          1258             126.347826
# 6     1991          1380             112.312500
# 7     1992          1380              99.642857
# 8     1993          1380             101.875000
# 9     1994          1380             106.583333
# 10    1995          1206             102.833333
# 11    1996          1206             103.600000
# 12    1997          1254              94.142857
# 13    1998          1395             101.153846
# 14    1999          1317              95.750000
# 15    2000          1395              95.647059
# 16    2001          1395              99.315789
# 17    2002          1242              92.888889
# 18    2003          1395              88.222222
# 19    2004          1194              92.142857
# 20    2005          1311              91.333333
# 21    2006          1190              89.533333
# 22    2007          1440              99.400000
# 23    2008          1440              94.500000
# 24    2009          1377              96.200000
# 25    2010          1440              95.000000
# 26    2011          1449              90.130435
# 27    2012          1370              87.400000
# 28    2013          1377              86.500000
# 29    2014          1322              92.600000
# 30    2015          1322              90.733333
# 31    2016          1146              97.142857

# %% [markdown]
# **Q**: Create a new DataFrame that counts the number of wins for each team in each season. This will involve grouping by both season and winning team, and then using the count() function.

# %%
# Group the DataFrame by season and winning team
grouped_df = df.groupby(['Season', 'Wteam'])

# Count the number of wins for each team in each season
wins_per_team_per_season = grouped_df.size().reset_index(name='Wins')

# Print the resulting DataFrame
print("Number of wins for each team in each season:")
display(wins_per_team_per_season)
# Out:
# Number of wins for each team in each season:
#        Season  Wteam  Wins
# 0        1985   1102     5
# 1        1985   1103     9
# 2        1985   1104    21
# 3        1985   1106    10
# 4        1985   1108    19
# ...       ...    ...   ...
# 10167    2016   1460    20
# 10168    2016   1461    12
# 10169    2016   1462    27
# 10170    2016   1463    21
# 10171    2016   1464     9
#
# [10172 rows x 3 columns]

# %% [markdown]
# **Q**: For each season, find the team with the most wins. This will involve creating a DataFrame similar to the one in task 5, and then using the idxmax() function for each season.

# %%
# Group the DataFrame by season and winning team
grouped_df = df.groupby(['Season', 'Wteam'])

# Count the number of wins for each team in each season
wins_per_team_per_season = grouped_df.size().reset_index(name='Wins')

# Find the team with the most wins for each season
teams_with_most_wins_per_season = wins_per_team_per_season.groupby('Season')['Wins'].idxmax()
teams_with_most_wins_per_season = wins_per_team_per_season.loc[teams_with_most_wins_per_season]

# Print the resulting DataFrame
print("Team with the most wins for each season:")
display(teams_with_most_wins_per_season)
# Out:
# Team with the most wins for each season:
#       Season  Wteam  Wins
# 217     1985   1385    27
# 342     1986   1181    32
# 818     1987   1424    33
# 861     1988   1112    31
# 1323    1989   1328    28
# 1551    1990   1247    29
# 1739    1991   1116    30
# 2088    1992   1181    28
# 2423    1993   1231    28
# 2665    1994   1163    27
# 2928    1995   1116    26
# 3357    1996   1269    31
# 3638    1997   1242    31
# 3943    1998   1242    33
# 4201    1999   1181    32
# 4709    2000   1409    29
# 4829    2001   1181    29
# 5121    2002   1153    30
# 5456    2003   1166    29
# 5981    2004   1390    29
# 6165    2005   1228    32
# 6452    2006   1181    30
# 6841    2007   1242    30
# 7209    2008   1272    33
# 7552    2009   1272    31
# 7870    2010   1242    32
# 8217    2011   1242    32
# 8565    2012   1246    32
# 8878    2013   1211    30
# 9462    2014   1455    33
# 9609    2015   1246    34
# 9955    2016   1242    29

# %% [markdown]
# **Q**: Group the DataFrame by losing team and find the average losing score for each team across all seasons. Compare this with the average winning score for each team from task 3. Are there teams that have a higher average losing score than winning score?

# %%
# Group the DataFrame by losing team
grouped_losing_df = df.groupby('Lteam')

# Calculate the average losing score for each team across all seasons
average_losing_score = grouped_losing_df['Lscore'].mean()

# Print the resulting DataFrame
print("Average losing score for each team across all seasons:")
display(average_losing_score)
# Out:
# Average losing score for each team across all seasons:
# Lteam
# 1101    60.586207
# 1102    59.201507
# 1103    64.117347
# 1104    64.374317
# 1105    61.675373
#           ...
# 1460    63.082915
# 1461    64.661972
# 1462    68.216117
# 1463    60.829213
# 1464    65.187063
# Name: Lscore, Length: 364, dtype: float64

# %% [markdown]
# I am creating a dataframe that is easier to comprehend by placing the average winning score and losing score for different teams side by side.

# %%
# Group the DataFrame by losing team
grouped_losing_df = df.groupby('Lteam')

# Calculate the average losing score for each team across all seasons
average_losing_score = grouped_losing_df['Lscore'].mean()

# Group the DataFrame by winning team and calculate the average winning score for each team across all seasons
average_winning_score = df.groupby('Wteam')['Wscore'].mean()

# Merge the average losing score and average winning score dataframes
merged_scores_df = average_losing_score.to_frame().merge(average_winning_score.to_frame(), left_index=True, right_index=True)

# Rename the columns
merged_scores_df.columns = ['Average Losing Score', 'Average Winning Score']

# Print the merged DataFrame
print("Average losing score and average winning score for each team:")
display(merged_scores_df)
# Out:
# Average losing score and average winning score for each team:
#        Average Losing Score  Average Winning Score
# Lteam
# 1101              60.586207              78.111111
# 1102              59.201507              69.893204
# 1103              64.117347              75.839768
# 1104              64.374317              75.825944
# 1105              61.675373              74.960894
# ...                     ...                    ...
# 1460              63.082915              75.531469
# 1461              64.661972              75.170082
# 1462              68.216117              79.906021
# 1463              60.829213              71.720102
# 1464              65.187063              73.926056
#
# [364 rows x 2 columns]

# %%
# Filter the merged DataFrame to include only the teams with higher average Lscore than Wscore
filtered_teams = merged_scores_df[merged_scores_df['Average Losing Score'] > merged_scores_df['Average Winning Score']]

# Print the filtered teams
print("Teams with a higher average Lscore than Wscore:")
display(filtered_teams)
# Out:
# Teams with a higher average Lscore than Wscore:
# Empty DataFrame
# Columns: [Average Losing Score, Average Winning Score]
# Index: []

# %% [markdown]
# The conclusion must be that there are no teams that have an average Lscore higher than Wscore.

# %% [markdown]
# # Dataframe Iteration

# %% [markdown]
# In order to iterate through dataframes, we can use the **iterrows()** function. Below is an example of what the first two rows look like. Each row in iterrows is a Series object

# %%
for index, row in df.iterrows():
    print(row)
    if index == 1:
        break
# Out:
# Season             1985
# Daynum               20
# Wteam              1228
# Wscore               81
# Lteam              1328
# Lscore               64
# Wloc                  N
# Numot                 0
# ScoreDifference      17
# Name: 0, dtype: object
# Season             1985
# Daynum               25
# Wteam              1106
# Wscore               77
# Lteam              1354
# Lscore               70
# Wloc                  H
# Numot                 0
# ScoreDifference       7
# Name: 1, dtype: object

# %% [markdown]
# **Q**: Create a new column 'HighScoringGame' that is 'Yes' if the winning score is greater than 100 and 'No' otherwise. This will require iterating over the rows of the DataFrame and checking the value of the winning score for each row.

# %%
# Create a new column 'HighScoringGame'
df['HighScoringGame'] = df['Wscore'].apply(lambda x: 'Yes' if x > 100 else 'No')

# Print the updated DataFrame
print("Updated DataFrame with 'HighScoringGame' column:")
display(df)
# Out:
# Updated DataFrame with 'HighScoringGame' column:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  \
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
#         ScoreDifference HighScoringGame
# 0                    17              No
# 1                     7              No
# 2                     7              No
# 3                    16              No
# 4                    12              No
# ...                 ...             ...
# 145284               20              No
# 145285               14              No
# 145286                5              No
# 145287                4              No
# 145288               13              No
#
# [145289 rows x 10 columns]

# %% [markdown]
# Since I couldn't identify any 'Yes' values in the above DataFrame, I am trying to create one that extracts the results with 'Yes' just to verify if the code is correct.

# %%
# Filter the DataFrame to include only rows with 'HighScoringGame' as 'Yes'
high_scoring_games_df = df[df['HighScoringGame'] == 'Yes']

# Print the filtered DataFrame
print("DataFrame with 'HighScoringGame' as 'Yes':")
display(high_scoring_games_df)
# Out:
# DataFrame with 'HighScoringGame' as 'Yes':
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  \
# 10        1985      25   1307     103   1288      71    H      0
# 25        1985      26   1196     106   1416      55    H      0
# 35        1985      26   1286     109   1186      64    H      0
# 42        1985      26   1375     104   1126      68    H      0
# 50        1985      26   1439     102   1330      76    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 144999    2016     124   1267     108   1379     106    H      1
# 145135    2016     128   1266     101   1385      93    N      0
# 145148    2016     128   1424     108   1102     102    N      3
# 145218    2016     130   1163     104   1153      97    N      4
# 145245    2016     130   1372     104   1223      68    N      0
#
#         ScoreDifference HighScoringGame
# 10                   32             Yes
# 25                   51             Yes
# 35                   45             Yes
# 42                   36             Yes
# 50                   26             Yes
# ...                 ...             ...
# 144999                2             Yes
# 145135                8             Yes
# 145148                6             Yes
# 145218                7             Yes
# 145245               36             Yes
#
# [4880 rows x 10 columns]

# %% [markdown]
# **Q**: Calculate the total number of games played by each team, whether they won or lost. This will require iterating over the rows of the DataFrame and updating a dictionary that keeps track of the number of games for each team.

# %%
# Initialize a dictionary to keep track of the number of games for each team
team_games = {}

# Iterate over the rows of the DataFrame
for index, row in df.iterrows():
    # Get the winning team and losing team for the current row
    winning_team = row['Wteam']
    losing_team = row['Lteam']
    
    # Update the number of games for the winning team
    if winning_team in team_games:
        team_games[winning_team] += 1
    else:
        team_games[winning_team] = 1
    
    # Update the number of games for the losing team
    if losing_team in team_games:
        team_games[losing_team] += 1
    else:
        team_games[losing_team] = 1

# Print the total number of games played by each team
print("Total number of games played by each team:")
for team, games in team_games.items():
    print(f"{team}: {games} games")
# Out:
# Total number of games played by each team:
# 1228: 992 games
# 1328: 968 games
# 1106: 855 games
# 1354: 906 games
# 1112: 981 games
# 1223: 363 games
# 1165: 833 games
# 1432: 69 games
# 1192: 908 games
# 1447: 903 games
# 1218: 931 games
# 1337: 922 games
# 1226: 847 games
# 1242: 993 games
# 1268: 969 games
# 1260: 914 games
# 1133: 949 games
# 1305: 922 games
# 1424: 974 games
# 1307: 969 games
# 1288: 925 games
# 1344: 951 games
# 1438: 952 games
# 1374: 916 games
# 1411: 903 games
# 1412: 962 games
# 1397: 963 games
# 1417: 966 games
# 1225: 880 games
# 1116: 980 games
# 1368: 808 games
# 1120: 936 games
# 1391: 879 games
# 1135: 847 games
# 1306: 898 games
# 1143: 947 games
# 1388: 897 games
# 1153: 970 games
# 1184: 863 games
# 1159: 887 games
# 1171: 829 games
# 1216: 930 games
# 1173: 960 games
# 1134: 200 games
# 1177: 942 games
# 1296: 879 games
# 1193: 942 games
# 1265: 934 games
# 1196: 981 games
# 1416: 881 games
# 1206: 938 games
# 1137: 912 games
# 1210: 972 games
# 1149: 824 games
# 1211: 921 games
# 1102: 840 games
# 1234: 968 games
# 1114: 910 games
# 1332: 927 games
# 1243: 927 games
# 1317: 883 games
# 1257: 994 games
# 1231: 969 games
# 1277: 966 games
# 1145: 934 games
# 1278: 948 games
# 1453: 912 games
# 1286: 851 games
# 1186: 849 games
# 1301: 979 games
# 1144: 850 games
# 1325: 942 games
# 1384: 887 games
# 1326: 968 games
# 1248: 896 games
# 1287: 857 games
# 1339: 879 games
# 1334: 899 games
# 1365: 907 games
# 1375: 896 games
# 1126: 906 games
# 1403: 939 games
# 1152: 865 games
# 1423: 931 games
# 1347: 858 games
# 1429: 930 games
# 1428: 931 games
# 1437: 983 games
# 1436: 911 games
# 1172: 879 games
# 1439: 946 games
# 1330: 963 games
# 1443: 942 games
# 1121: 175 games
# 1455: 947 games
# 1249: 873 games
# 1241: 942 games
# 1440: 825 games
# 1314: 1010 games
# 1200: 922 games
# 1323: 950 games
# 1264: 928 games
# 1458: 951 games
# 1104: 975 games
# 1160: 928 games
# 1414: 922 games
# 1181: 1013 games
# 1387: 956 games
# 1183: 871 games
# 1247: 943 games
# 1284: 932 games
# 1402: 847 games
# 1276: 959 games
# 1178: 920 games
# 1364: 890 games
# 1338: 962 games
# 1290: 875 games
# 1376: 945 games
# 1378: 936 games
# 1202: 856 games
# 1396: 979 games
# 1180: 930 games
# 1398: 870 games
# 1399: 860 games
# 1155: 950 games
# 1258: 898 games
# 1448: 947 games
# 1464: 856 games
# 1124: 906 games
# 1341: 857 games
# 1130: 951 games
# 1254: 898 games
# 1204: 862 games
# 1151: 899 games
# 1233: 957 games
# 1220: 933 games
# 1246: 999 games
# 1405: 921 games
# 1280: 946 games
# 1238: 920 games
# 1308: 935 games
# 1431: 937 games
# 1253: 915 games
# 1363: 889 games
# 1348: 938 games
# 1373: 950 games
# 1379: 896 games
# 1270: 861 games
# 1409: 966 games
# 1331: 809 games
# 1444: 916 games
# 1434: 902 games
# 1451: 866 games
# 1139: 923 games
# 1442: 840 games
# 1154: 820 games
# 1456: 891 games
# 1229: 951 games
# 1227: 917 games
# 1259: 913 games
# 1406: 926 games
# 1261: 956 games
# 1272: 992 games
# 1117: 891 games
# 1273: 896 games
# 1163: 977 games
# 1318: 942 games
# 1360: 889 games
# 1393: 993 games
# 1419: 894 games
# 1418: 912 games
# 1281: 977 games
# 1161: 905 games
# 1109: 169 games
# 1309: 840 games
# 1298: 894 games
# 1321: 912 games
# 1285: 865 games
# 1271: 887 games
# 1353: 939 games
# 1351: 929 games
# 1359: 874 games
# 1267: 909 games
# 1361: 915 games
# 1386: 958 games
# 1400: 982 games
# 1322: 854 games
# 1433: 975 games
# 1187: 861 games
# 1245: 927 games
# 1111: 876 games
# 1150: 942 games
# 1119: 868 games
# 1141: 872 games
# 1221: 929 games
# 1122: 903 games
# 1185: 900 games
# 1199: 949 games
# 1201: 947 games
# 1212: 837 games
# 1197: 896 games
# 1140: 965 games
# 1292: 888 games
# 1162: 831 games
# 1319: 843 games
# 1239: 891 games
# 1320: 913 games
# 1371: 946 games
# 1349: 888 games
# 1222: 930 games
# 1382: 914 games
# 1383: 898 games
# 1385: 954 games
# 1390: 932 games
# 1425: 944 games
# 1435: 961 games
# 1463: 838 games
# 1441: 854 games
# 1449: 938 games
# 1123: 906 games
# 1103: 910 games
# 1129: 907 games
# 1209: 891 games
# 1156: 900 games
# 1336: 926 games
# 1174: 913 games
# 1343: 832 games
# 1232: 913 games
# 1203: 933 games
# 1110: 910 games
# 1335: 880 games
# 1283: 952 games
# 1235: 950 games
# 1166: 957 games
# 1311: 839 games
# 1256: 925 games
# 1147: 698 games
# 1250: 898 games
# 1266: 951 games
# 1452: 945 games
# 1269: 946 games
# 1208: 954 games
# 1310: 949 games
# 1329: 941 games
# 1333: 911 games
# 1345: 966 games
# 1263: 898 games
# 1352: 925 games
# 1380: 862 games
# 1446: 48 games
# 1427: 858 games
# 1113: 937 games
# 1408: 808 games
# 1410: 831 games
# 1350: 959 games
# 1450: 913 games
# 1462: 954 games
# 1131: 945 games
# 1190: 891 games
# 1168: 891 games
# 1179: 914 games
# 1304: 953 games
# 1224: 907 games
# 1356: 953 games
# 1426: 859 games
# 1215: 147 games
# 1132: 895 games
# 1217: 828 games
# 1389: 928 games
# 1395: 943 games
# 1461: 914 games
# 1279: 927 games
# 1275: 932 games
# 1293: 886 games
# 1191: 928 games
# 1299: 870 games
# 1401: 940 games
# 1175: 890 games
# 1327: 22 games
# 1207: 923 games
# 1108: 866 games
# 1182: 924 games
# 1274: 915 games
# 1362: 867 games
# 1164: 893 games
# 1118: 27 games
# 1420: 845 games
# 1457: 801 games
# 1148: 844 games
# 1372: 795 games
# 1157: 784 games
# 1421: 799 games
# 1358: 806 games
# 1460: 827 games
# 1198: 812 games
# 1291: 815 games
# 1381: 735 games
# 1251: 755 games
# 1282: 745 games
# 1169: 724 games
# 1302: 200 games
# 1454: 737 games
# 1170: 660 games
# 1138: 728 games
# 1158: 720 games
# 1422: 719 games
# 1369: 682 games
# 1404: 643 games
# 1194: 647 games
# 1407: 639 games
# 1142: 597 games
# 1214: 627 games
# 1459: 575 games
# 1240: 568 games
# 1313: 563 games
# 1115: 520 games
# 1176: 526 games
# 1346: 522 games
# 1237: 519 games
# 1340: 497 games
# 1107: 512 games
# 1357: 500 games
# 1324: 506 games
# 1189: 481 games
# 1125: 506 games
# 1105: 447 games
# 1392: 493 games
# 1219: 466 games
# 1127: 442 games
# 1289: 48 games
# 1415: 418 games
# 1236: 400 games
# 1394: 390 games
# 1205: 405 games
# 1128: 106 games
# 1252: 401 games
# 1366: 384 games
# 1294: 336 games
# 1255: 344 games
# 1430: 325 games
# 1413: 348 games
# 1355: 327 games
# 1244: 322 games
# 1295: 308 games
# 1316: 327 games
# 1445: 107 games
# 1312: 276 games
# 1146: 267 games
# 1167: 260 games
# 1300: 252 games
# 1367: 267 games
# 1342: 260 games
# 1195: 273 games
# 1188: 207 games
# 1377: 210 games
# 1315: 217 games
# 1136: 240 games
# 1370: 222 games
# 1303: 129 games
# 1297: 113 games
# 1213: 84 games
# 1262: 83 games
# 1101: 76 games
# 1230: 64 games

# %% [markdown]
# **Q**: For each season, find the game with the highest score difference (winning score - losing score). This will require iterating over the rows of the DataFrame, keeping track of the highest score difference for each season, and updating it if a game with a higher score difference is found.

# %%
# Create a dictionary to store the highest score difference for each season
highest_score_diff_per_season = {}

# Iterate over the rows of the DataFrame
for index, row in df.iterrows():
    season = row['Season']
    score_diff = row['Wscore'] - row['Lscore']
    
    # Check if the season already exists in the dictionary
    if season in highest_score_diff_per_season:
        # If the current score difference is higher, update the value in the dictionary
        if score_diff > highest_score_diff_per_season[season]['score_diff']:
            highest_score_diff_per_season[season] = {
                'score_diff': score_diff,
                'game': index
            }
    else:
        # If the season is not in the dictionary, initialize it with the current score difference
        highest_score_diff_per_season[season] = {
            'score_diff': score_diff,
            'game': index
        }


# Print the game with the highest score difference for each season
for season, result in highest_score_diff_per_season.items():
    game_index = result['game']
    score_diff = result['score_diff']
    print(f"Season: {season}, Game with highest score difference: {game_index}, Score Difference: {score_diff}")
# Out:
# Season: 1985, Game with highest score difference: 236, Score Difference: 60
# Season: 1986, Game with highest score difference: 4731, Score Difference: 84
# Season: 1987, Game with highest score difference: 8240, Score Difference: 73
# Season: 1988, Game with highest score difference: 12046, Score Difference: 68
# Season: 1989, Game with highest score difference: 16677, Score Difference: 70
# Season: 1990, Game with highest score difference: 19502, Score Difference: 76
# Season: 1991, Game with highest score difference: 25161, Score Difference: 68
# Season: 1992, Game with highest score difference: 27997, Score Difference: 82
# Season: 1993, Game with highest score difference: 33858, Score Difference: 81
# Season: 1994, Game with highest score difference: 36404, Score Difference: 69
# Season: 1995, Game with highest score difference: 39858, Score Difference: 74
# Season: 1996, Game with highest score difference: 44653, Score Difference: 91
# Season: 1997, Game with highest score difference: 49033, Score Difference: 80
# Season: 1998, Game with highest score difference: 52600, Score Difference: 66
# Season: 1999, Game with highest score difference: 57618, Score Difference: 75
# Season: 2000, Game with highest score difference: 60616, Score Difference: 75
# Season: 2001, Game with highest score difference: 65999, Score Difference: 75
# Season: 2002, Game with highest score difference: 70737, Score Difference: 59
# Season: 2003, Game with highest score difference: 74791, Score Difference: 72
# Season: 2004, Game with highest score difference: 79181, Score Difference: 70
# Season: 2005, Game with highest score difference: 83372, Score Difference: 64
# Season: 2006, Game with highest score difference: 89542, Score Difference: 72
# Season: 2007, Game with highest score difference: 94507, Score Difference: 74
# Season: 2008, Game with highest score difference: 97737, Score Difference: 70
# Season: 2009, Game with highest score difference: 103723, Score Difference: 68
# Season: 2010, Game with highest score difference: 108405, Score Difference: 75
# Season: 2011, Game with highest score difference: 114015, Score Difference: 69
# Season: 2012, Game with highest score difference: 118699, Score Difference: 62
# Season: 2013, Game with highest score difference: 124057, Score Difference: 58
# Season: 2014, Game with highest score difference: 131373, Score Difference: 74
# Season: 2015, Game with highest score difference: 134590, Score Difference: 69
# Season: 2016, Game with highest score difference: 140040, Score Difference: 73

# %% [markdown]
# Remember, iterating over a DataFrame should generally be avoided if a vectorized operation can be used instead, as vectorized operations are usually much faster. However, these tasks are designed to give practice with DataFrame iteration for cases where it might be necessary.

# %% [markdown]
# Vectorized Operation Example: Create a new column 'HighScoringGame' in the DataFrame using a vectorized operation. This column should contain 'Yes' if the winning score is greater than 100 and 'No' otherwise. Use the np.where function from the numpy library for this task.

# %%
import numpy as np
df['HighScoringGame'] = np.where(df['Wscore'] > 100, 'Yes', 'No')

# %% [markdown]
# **Q**: Vectorized Operation: Calculate the total number of games played by each team, whether they won or lost. Instead of iterating over the DataFrame, use the value_counts() function on the winning team and losing team columns separately, and then add the two Series together.

# %%
# Calculate the count of games for each team using value_counts() on the winning team and losing team columns separately
games_played_winning = df['Wteam'].value_counts()
games_played_losing = df['Lteam'].value_counts()

# Add the two Series together to get the total number of games played by each team
games_played = games_played_winning.add(games_played_losing, fill_value=0)

# Print the number of games played by each team
for team, count in games_played.items():
    print(f"Team: {team}, Games Played: {count}")
# Out:
# Team: 1101, Games Played: 76
# Team: 1102, Games Played: 840
# Team: 1103, Games Played: 910
# Team: 1104, Games Played: 975
# Team: 1105, Games Played: 447
# Team: 1106, Games Played: 855
# Team: 1107, Games Played: 512
# Team: 1108, Games Played: 866
# Team: 1109, Games Played: 169
# Team: 1110, Games Played: 910
# Team: 1111, Games Played: 876
# Team: 1112, Games Played: 981
# Team: 1113, Games Played: 937
# Team: 1114, Games Played: 910
# Team: 1115, Games Played: 520
# Team: 1116, Games Played: 980
# Team: 1117, Games Played: 891
# Team: 1118, Games Played: 27
# Team: 1119, Games Played: 868
# Team: 1120, Games Played: 936
# Team: 1121, Games Played: 175
# Team: 1122, Games Played: 903
# Team: 1123, Games Played: 906
# Team: 1124, Games Played: 906
# Team: 1125, Games Played: 506
# Team: 1126, Games Played: 906
# Team: 1127, Games Played: 442
# Team: 1128, Games Played: 106
# Team: 1129, Games Played: 907
# Team: 1130, Games Played: 951
# Team: 1131, Games Played: 945
# Team: 1132, Games Played: 895
# Team: 1133, Games Played: 949
# Team: 1134, Games Played: 200
# Team: 1135, Games Played: 847
# Team: 1136, Games Played: 240
# Team: 1137, Games Played: 912
# Team: 1138, Games Played: 728
# Team: 1139, Games Played: 923
# Team: 1140, Games Played: 965
# Team: 1141, Games Played: 872
# Team: 1142, Games Played: 597
# Team: 1143, Games Played: 947
# Team: 1144, Games Played: 850
# Team: 1145, Games Played: 934
# Team: 1146, Games Played: 267
# Team: 1147, Games Played: 698
# Team: 1148, Games Played: 844
# Team: 1149, Games Played: 824
# Team: 1150, Games Played: 942
# Team: 1151, Games Played: 899
# Team: 1152, Games Played: 865
# Team: 1153, Games Played: 970
# Team: 1154, Games Played: 820
# Team: 1155, Games Played: 950
# Team: 1156, Games Played: 900
# Team: 1157, Games Played: 784
# Team: 1158, Games Played: 720
# Team: 1159, Games Played: 887
# Team: 1160, Games Played: 928
# Team: 1161, Games Played: 905
# Team: 1162, Games Played: 831
# Team: 1163, Games Played: 977
# Team: 1164, Games Played: 893
# Team: 1165, Games Played: 833
# Team: 1166, Games Played: 957
# Team: 1167, Games Played: 260
# Team: 1168, Games Played: 891
# Team: 1169, Games Played: 724
# Team: 1170, Games Played: 660
# Team: 1171, Games Played: 829
# Team: 1172, Games Played: 879
# Team: 1173, Games Played: 960
# Team: 1174, Games Played: 913
# Team: 1175, Games Played: 890
# Team: 1176, Games Played: 526
# Team: 1177, Games Played: 942
# Team: 1178, Games Played: 920
# Team: 1179, Games Played: 914
# Team: 1180, Games Played: 930
# Team: 1181, Games Played: 1013
# Team: 1182, Games Played: 924
# Team: 1183, Games Played: 871
# Team: 1184, Games Played: 863
# Team: 1185, Games Played: 900
# Team: 1186, Games Played: 849
# Team: 1187, Games Played: 861
# Team: 1188, Games Played: 207
# Team: 1189, Games Played: 481
# Team: 1190, Games Played: 891
# Team: 1191, Games Played: 928
# Team: 1192, Games Played: 908
# Team: 1193, Games Played: 942
# Team: 1194, Games Played: 647
# Team: 1195, Games Played: 273
# Team: 1196, Games Played: 981
# Team: 1197, Games Played: 896
# Team: 1198, Games Played: 812
# Team: 1199, Games Played: 949
# Team: 1200, Games Played: 922
# Team: 1201, Games Played: 947
# Team: 1202, Games Played: 856
# Team: 1203, Games Played: 933
# Team: 1204, Games Played: 862
# Team: 1205, Games Played: 405
# Team: 1206, Games Played: 938
# Team: 1207, Games Played: 923
# Team: 1208, Games Played: 954
# Team: 1209, Games Played: 891
# Team: 1210, Games Played: 972
# Team: 1211, Games Played: 921
# Team: 1212, Games Played: 837
# Team: 1213, Games Played: 84
# Team: 1214, Games Played: 627
# Team: 1215, Games Played: 147
# Team: 1216, Games Played: 930
# Team: 1217, Games Played: 828
# Team: 1218, Games Played: 931
# Team: 1219, Games Played: 466
# Team: 1220, Games Played: 933
# Team: 1221, Games Played: 929
# Team: 1222, Games Played: 930
# Team: 1223, Games Played: 363
# Team: 1224, Games Played: 907
# Team: 1225, Games Played: 880
# Team: 1226, Games Played: 847
# Team: 1227, Games Played: 917
# Team: 1228, Games Played: 992
# Team: 1229, Games Played: 951
# Team: 1230, Games Played: 64
# Team: 1231, Games Played: 969
# Team: 1232, Games Played: 913
# Team: 1233, Games Played: 957
# Team: 1234, Games Played: 968
# Team: 1235, Games Played: 950
# Team: 1236, Games Played: 400
# Team: 1237, Games Played: 519
# Team: 1238, Games Played: 920
# Team: 1239, Games Played: 891
# Team: 1240, Games Played: 568
# Team: 1241, Games Played: 942
# Team: 1242, Games Played: 993
# Team: 1243, Games Played: 927
# Team: 1244, Games Played: 322
# Team: 1245, Games Played: 927
# Team: 1246, Games Played: 999
# Team: 1247, Games Played: 943
# Team: 1248, Games Played: 896
# Team: 1249, Games Played: 873
# Team: 1250, Games Played: 898
# Team: 1251, Games Played: 755
# Team: 1252, Games Played: 401
# Team: 1253, Games Played: 915
# Team: 1254, Games Played: 898
# Team: 1255, Games Played: 344
# Team: 1256, Games Played: 925
# Team: 1257, Games Played: 994
# Team: 1258, Games Played: 898
# Team: 1259, Games Played: 913
# Team: 1260, Games Played: 914
# Team: 1261, Games Played: 956
# Team: 1262, Games Played: 83
# Team: 1263, Games Played: 898
# Team: 1264, Games Played: 928
# Team: 1265, Games Played: 934
# Team: 1266, Games Played: 951
# Team: 1267, Games Played: 909
# Team: 1268, Games Played: 969
# Team: 1269, Games Played: 946
# Team: 1270, Games Played: 861
# Team: 1271, Games Played: 887
# Team: 1272, Games Played: 992
# Team: 1273, Games Played: 896
# Team: 1274, Games Played: 915
# Team: 1275, Games Played: 932
# Team: 1276, Games Played: 959
# Team: 1277, Games Played: 966
# Team: 1278, Games Played: 948
# Team: 1279, Games Played: 927
# Team: 1280, Games Played: 946
# Team: 1281, Games Played: 977
# Team: 1282, Games Played: 745
# Team: 1283, Games Played: 952
# Team: 1284, Games Played: 932
# Team: 1285, Games Played: 865
# Team: 1286, Games Played: 851
# Team: 1287, Games Played: 857
# Team: 1288, Games Played: 925
# Team: 1289, Games Played: 48
# Team: 1290, Games Played: 875
# Team: 1291, Games Played: 815
# Team: 1292, Games Played: 888
# Team: 1293, Games Played: 886
# Team: 1294, Games Played: 336
# Team: 1295, Games Played: 308
# Team: 1296, Games Played: 879
# Team: 1297, Games Played: 113
# Team: 1298, Games Played: 894
# Team: 1299, Games Played: 870
# Team: 1300, Games Played: 252
# Team: 1301, Games Played: 979
# Team: 1302, Games Played: 200
# Team: 1303, Games Played: 129
# Team: 1304, Games Played: 953
# Team: 1305, Games Played: 922
# Team: 1306, Games Played: 898
# Team: 1307, Games Played: 969
# Team: 1308, Games Played: 935
# Team: 1309, Games Played: 840
# Team: 1310, Games Played: 949
# Team: 1311, Games Played: 839
# Team: 1312, Games Played: 276
# Team: 1313, Games Played: 563
# Team: 1314, Games Played: 1010
# Team: 1315, Games Played: 217
# Team: 1316, Games Played: 327
# Team: 1317, Games Played: 883
# Team: 1318, Games Played: 942
# Team: 1319, Games Played: 843
# Team: 1320, Games Played: 913
# Team: 1321, Games Played: 912
# Team: 1322, Games Played: 854
# Team: 1323, Games Played: 950
# Team: 1324, Games Played: 506
# Team: 1325, Games Played: 942
# Team: 1326, Games Played: 968
# Team: 1327, Games Played: 22
# Team: 1328, Games Played: 968
# Team: 1329, Games Played: 941
# Team: 1330, Games Played: 963
# Team: 1331, Games Played: 809
# Team: 1332, Games Played: 927
# Team: 1333, Games Played: 911
# Team: 1334, Games Played: 899
# Team: 1335, Games Played: 880
# Team: 1336, Games Played: 926
# Team: 1337, Games Played: 922
# Team: 1338, Games Played: 962
# Team: 1339, Games Played: 879
# Team: 1340, Games Played: 497
# Team: 1341, Games Played: 857
# Team: 1342, Games Played: 260
# Team: 1343, Games Played: 832
# Team: 1344, Games Played: 951
# Team: 1345, Games Played: 966
# Team: 1346, Games Played: 522
# Team: 1347, Games Played: 858
# Team: 1348, Games Played: 938
# Team: 1349, Games Played: 888
# Team: 1350, Games Played: 959
# Team: 1351, Games Played: 929
# Team: 1352, Games Played: 925
# Team: 1353, Games Played: 939
# Team: 1354, Games Played: 906
# Team: 1355, Games Played: 327
# Team: 1356, Games Played: 953
# Team: 1357, Games Played: 500
# Team: 1358, Games Played: 806
# Team: 1359, Games Played: 874
# Team: 1360, Games Played: 889
# Team: 1361, Games Played: 915
# Team: 1362, Games Played: 867
# Team: 1363, Games Played: 889
# Team: 1364, Games Played: 890
# Team: 1365, Games Played: 907
# Team: 1366, Games Played: 384
# Team: 1367, Games Played: 267
# Team: 1368, Games Played: 808
# Team: 1369, Games Played: 682
# Team: 1370, Games Played: 222
# Team: 1371, Games Played: 946
# Team: 1372, Games Played: 795
# Team: 1373, Games Played: 950
# Team: 1374, Games Played: 916
# Team: 1375, Games Played: 896
# Team: 1376, Games Played: 945
# Team: 1377, Games Played: 210
# Team: 1378, Games Played: 936
# Team: 1379, Games Played: 896
# Team: 1380, Games Played: 862
# Team: 1381, Games Played: 735
# Team: 1382, Games Played: 914
# Team: 1383, Games Played: 898
# Team: 1384, Games Played: 887
# Team: 1385, Games Played: 954
# Team: 1386, Games Played: 958
# Team: 1387, Games Played: 956
# Team: 1388, Games Played: 897
# Team: 1389, Games Played: 928
# Team: 1390, Games Played: 932
# Team: 1391, Games Played: 879
# Team: 1392, Games Played: 493
# Team: 1393, Games Played: 993
# Team: 1394, Games Played: 390
# Team: 1395, Games Played: 943
# Team: 1396, Games Played: 979
# Team: 1397, Games Played: 963
# Team: 1398, Games Played: 870
# Team: 1399, Games Played: 860
# Team: 1400, Games Played: 982
# Team: 1401, Games Played: 940
# Team: 1402, Games Played: 847
# Team: 1403, Games Played: 939
# Team: 1404, Games Played: 643
# Team: 1405, Games Played: 921
# Team: 1406, Games Played: 926
# Team: 1407, Games Played: 639
# Team: 1408, Games Played: 808
# Team: 1409, Games Played: 966
# Team: 1410, Games Played: 831
# Team: 1411, Games Played: 903
# Team: 1412, Games Played: 962
# Team: 1413, Games Played: 348
# Team: 1414, Games Played: 922
# Team: 1415, Games Played: 418
# Team: 1416, Games Played: 881
# Team: 1417, Games Played: 966
# Team: 1418, Games Played: 912
# Team: 1419, Games Played: 894
# Team: 1420, Games Played: 845
# Team: 1421, Games Played: 799
# Team: 1422, Games Played: 719
# Team: 1423, Games Played: 931
# Team: 1424, Games Played: 974
# Team: 1425, Games Played: 944
# Team: 1426, Games Played: 859
# Team: 1427, Games Played: 858
# Team: 1428, Games Played: 931
# Team: 1429, Games Played: 930
# Team: 1430, Games Played: 325
# Team: 1431, Games Played: 937
# Team: 1432, Games Played: 69
# Team: 1433, Games Played: 975
# Team: 1434, Games Played: 902
# Team: 1435, Games Played: 961
# Team: 1436, Games Played: 911
# Team: 1437, Games Played: 983
# Team: 1438, Games Played: 952
# Team: 1439, Games Played: 946
# Team: 1440, Games Played: 825
# Team: 1441, Games Played: 854
# Team: 1442, Games Played: 840
# Team: 1443, Games Played: 942
# Team: 1444, Games Played: 916
# Team: 1445, Games Played: 107
# Team: 1446, Games Played: 48
# Team: 1447, Games Played: 903
# Team: 1448, Games Played: 947
# Team: 1449, Games Played: 938
# Team: 1450, Games Played: 913
# Team: 1451, Games Played: 866
# Team: 1452, Games Played: 945
# Team: 1453, Games Played: 912
# Team: 1454, Games Played: 737
# Team: 1455, Games Played: 947
# Team: 1456, Games Played: 891
# Team: 1457, Games Played: 801
# Team: 1458, Games Played: 951
# Team: 1459, Games Played: 575
# Team: 1460, Games Played: 827
# Team: 1461, Games Played: 914
# Team: 1462, Games Played: 954
# Team: 1463, Games Played: 838
# Team: 1464, Games Played: 856

# %% [markdown]
# **Q**: For each season, find the game with the highest score difference (winning score - losing score). Instead of iterating over the DataFrame, create a new column 'ScoreDifference' using vectorized subtraction, then use the groupby() function and idxmax() function to find the game with the highest score difference for each season.

# %%
# Create a new column 'ScoreDifference' using vectorized subtraction
df['ScoreDifference'] = df['Wscore'] - df['Lscore']

# Use groupby() and idxmax() to find the game with the highest score difference for each season
highest_score_diff_games = df.groupby('Season')['ScoreDifference'].idxmax()

# Retrieve the corresponding game information
highest_score_diff_info = df.loc[highest_score_diff_games, ['Season', 'Wteam', 'Lteam', 'Wscore', 'Lscore', 'ScoreDifference']]

# Print the game with the highest score difference for each season
print("Game with the highest score difference for each season:")
for _, game_info in highest_score_diff_info.iterrows():
    season = game_info['Season']
    winning_team = game_info['Wteam']
    losing_team = game_info['Lteam']
    winning_score = game_info['Wscore']
    losing_score = game_info['Lscore']
    score_difference = game_info['ScoreDifference']
    print(f"Season {season}: Highest score difference = {score_difference}, Game: {winning_team} ({winning_score}) vs {losing_team} ({losing_score})")
# Out:
# Game with the highest score difference for each season:
# Season 1985: Highest score difference = 60, Game: 1361 (128) vs 1288 (68)
# Season 1986: Highest score difference = 84, Game: 1314 (129) vs 1264 (45)
# Season 1987: Highest score difference = 73, Game: 1155 (112) vs 1118 (39)
# Season 1988: Highest score difference = 68, Game: 1328 (152) vs 1147 (84)
# Season 1989: Highest score difference = 70, Game: 1242 (115) vs 1135 (45)
# Season 1990: Highest score difference = 76, Game: 1181 (130) vs 1217 (54)
# Season 1991: Highest score difference = 68, Game: 1163 (115) vs 1148 (47)
# Season 1992: Highest score difference = 82, Game: 1116 (128) vs 1126 (46)
# Season 1993: Highest score difference = 81, Game: 1328 (146) vs 1197 (65)
# Season 1994: Highest score difference = 69, Game: 1228 (121) vs 1152 (52)
# Season 1995: Highest score difference = 74, Game: 1246 (124) vs 1404 (50)
# Season 1996: Highest score difference = 91, Game: 1409 (141) vs 1341 (50)
# Season 1997: Highest score difference = 80, Game: 1278 (114) vs 1106 (34)
# Season 1998: Highest score difference = 66, Game: 1395 (153) vs 1410 (87)
# Season 1999: Highest score difference = 75, Game: 1268 (132) vs 1317 (57)
# Season 2000: Highest score difference = 75, Game: 1261 (112) vs 1212 (37)
# Season 2001: Highest score difference = 75, Game: 1196 (125) vs 1197 (50)
# Season 2002: Highest score difference = 59, Game: 1328 (109) vs 1183 (50)
# Season 2003: Highest score difference = 72, Game: 1403 (107) vs 1311 (35)
# Season 2004: Highest score difference = 70, Game: 1328 (94) vs 1115 (24)
# Season 2005: Highest score difference = 64, Game: 1403 (119) vs 1421 (55)
# Season 2006: Highest score difference = 72, Game: 1400 (110) vs 1341 (38)
# Season 2007: Highest score difference = 74, Game: 1401 (101) vs 1212 (27)
# Season 2008: Highest score difference = 70, Game: 1182 (129) vs 1224 (59)
# Season 2009: Highest score difference = 68, Game: 1314 (116) vs 1421 (48)
# Season 2010: Highest score difference = 75, Game: 1397 (124) vs 1421 (49)
# Season 2011: Highest score difference = 69, Game: 1388 (121) vs 1152 (52)
# Season 2012: Highest score difference = 62, Game: 1345 (96) vs 1296 (34)
# Season 2013: Highest score difference = 58, Game: 1235 (98) vs 1105 (40)
# Season 2014: Highest score difference = 74, Game: 1256 (126) vs 1255 (52)
# Season 2015: Highest score difference = 69, Game: 1181 (113) vs 1342 (44)
# Season 2016: Highest score difference = 73, Game: 1139 (144) vs 1154 (71)

# %% [markdown]
# # Extracting Rows and Columns

# %% [markdown]
# The bracket indexing operator is one way to extract certain columns from a dataframe.

# %%
df[['Wscore', 'Lscore']].head()
# Out:
#    Wscore  Lscore
# 0      81      64
# 1      77      70
# 2      63      56
# 3      70      54
# 4      86      74

# %% [markdown]
# Notice that you can acheive the same result by using the loc function. Loc is a veryyyy versatile function that can help you in a lot of accessing and extracting tasks.

# %%
df.loc[:, ['Wscore', 'Lscore']].head()
# Out:
#    Wscore  Lscore
# 0      81      64
# 1      77      70
# 2      63      56
# 3      70      54
# 4      86      74

# %% [markdown]
# Note the difference is the return types when you use brackets and when you use double brackets.

# %%
type(df['Wscore'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Wscore']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# You've seen before that you can access columns through df['col name']. You can access rows by using slicing operations.

# %%
df[0:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  ScoreDifference  \
# 0    1985      20   1228      81   1328      64    N      0               17
# 1    1985      25   1106      77   1354      70    H      0                7
# 2    1985      25   1112      63   1223      56    H      0                7
#
#   HighScoringGame
# 0              No
# 1              No
# 2              No

# %% [markdown]
# Here's an equivalent using iloc

# %%
df.iloc[0:3,:]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# One of the big jobs of doing well in Kaggle competitions is that of data cleaning. A lot of times, the CSV file you're given (especially like in the Titanic dataset), you'll have a lot of missing values in the dataset, which you have to identify. The following **isnull** function will figure out if there are any missing values in the dataframe, and will then sum up the total for each column. In this case, we have a pretty clean dataset.

# %%
df.isnull().sum()
# Out:
# Season             0
# Daynum             0
# Wteam              0
# Wscore             0
# Lteam              0
# Lscore             0
# Wloc               0
# Numot              0
# ScoreDifference    0
# HighScoringGame    0
# dtype: int64

# %% [markdown]
# If you do end up having missing values in your datasets, be sure to get familiar with these two functions.
# * **dropna()** - This function allows you to drop all(or some) of the rows that have missing values.
# * **fillna()** - This function allows you replace the rows that have missing values with the value that you pass in.

# %% [markdown]
# # Other Useful Functions

# %% [markdown]
# * **drop()** - This function removes the column or row that you pass in (You also have the specify the axis).
# * **agg()** - The aggregate function lets you compute summary statistics about each group
# * **apply()** - Lets you apply a specific function to any/all elements in a Dataframe or Series
# * **get_dummies()** - Helpful for turning categorical data into one hot vectors.
# * **drop_duplicates()** - Lets you remove identical rows

# %% [markdown]
# # Lots of Other Great Resources

# %% [markdown]
# Pandas has been around for a while and there are a lot of other good resources if you're still interested on getting the most out of this library.
# * http://pandas.pydata.org/pandas-docs/stable/10min.html
# * https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python
# * http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/
# * https://www.dataquest.io/blog/pandas-python-tutorial/
# * https://drive.google.com/file/d/0ByIrJAE4KMTtTUtiVExiUGVkRkE/view
# * https://www.youtube.com/playlist?list=PL5-da3qGB5ICCsgW1MxlZ0Hq8LL5U3u9y
